# %% [markdown]
# # Overview
#
# A notebook for exploring the house prices data.

# %%
import pandas as pd

# %% [markdown]
# ## Step 1: load our data

# %%
houses_df = pd.read_csv("../data/houses.csv")

# %%
houses_df
# Out:
#              date          id     price  bedrooms  bathrooms  sqft_living  \
# 0      2014-10-13  7129300520  221900.0         3       1.00         1180
# 1      2014-12-09  6414100192  538000.0         3       2.25         2570
# 2      2015-02-25  5631500400  180000.0         2       1.00          770
# 3      2014-12-09  2487200875  604000.0         4       3.00         1960
# 4      2015-02-18  1954400510  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21608  2014-05-21   263000018  360000.0         3       2.50         1530
# 21609  2015-02-23  6600060120  400000.0         4       2.50         2310
# 21610  2014-06-23  1523300141  402101.0         2       0.75         1020
# 21611  2015-01-16   291310100  400000.0         3       2.50         1600
# 21612  2014-10-15  1523300157  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %% [markdown]
# ## Step 2: the top N% by price
#
# Implement a function that returns the houses in the top N% by price. You may want to start with the top 10%, and then generalise your function.
